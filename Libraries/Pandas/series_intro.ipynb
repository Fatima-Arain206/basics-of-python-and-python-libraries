# %%
import numpy as np
import pandas as pd

# Ek student ke marks ki Series banate hain
dtype=np.int32
marks_data = [85, 92, 78]
subjects = ['Math', 'Coding', 'Physics']

student_series = pd.Series(marks_data, index=subjects,dtype=np.int32)
print(student_series)
print(student_series.dtype)
# Out:
# Math       85
# Coding     92
# Physics    78
# dtype: int32
# int32

# %%
print(student_series['Math'])

mark_series=pd.Series(subjects, index=marks_data)
print(mark_series)

print(mark_series[85])

print(mark_series.dtype)
# Out:
# 85
# 85       Math
# 92     Coding
# 78    Physics
# dtype: str
# Math
# str

# %%
print(student_series.dtype)
# Out:
# int32
