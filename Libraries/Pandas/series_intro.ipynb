# %%
import pandas as pd

# Ek student ke marks ki Series banate hain
marks_data = [85, 92, 78]
subjects = ['Math', 'Coding', 'Physics']

student_series = pd.Series(marks_data, index=subjects)
print(student_series)
# Out:
# Math       85
# Coding     92
# Physics    78
# dtype: int64

# %%
print(student_series['Math'])

mark_series=pd.Series(subjects, index=marks_data)
print(mark_series)

print(mark_series[85])

print(mark_series.dtype)
# Out:
# 85
# 85       Math
# 92     Coding
# 78    Physics
# dtype: object
# Math
# object

# %%
print(student_series.dtype)
# Out:
# int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 print(student_series.dtype)
# ----> 2 dtype= pd.int32
#
# AttributeError: module 'pandas' has no attribute 'int32'
