# %%
import pandas as pd
jss=pd.read_json(r"data-dict_json.json")
jss
# Out:
#       Pakistan Saudi Arabia        Japan United Kingdom         Canada  \
# 0    Islamabad       Riyadh        Tokyo         London         Ottawa
# 1  240 Million   36 Million  125 Million     67 Million     40 Million
# 2   South Asia  Middle East    East Asia         Europe  North America
#
#          Egypt         Brazil   Australia
# 0        Cairo       Brasilia    Canberra
# 1  112 Million    215 Million  26 Million
# 2       Africa  South America     Oceania

# %%
f= open('data-dict_json.json') 
for i in f:
    print(i)

f.close()

# %%
dc= jss.to_dict(orient= 'list')
dc
# Out:
# {'Pakistan': ['Islamabad', '240 Million', 'South Asia'],
#  'Saudi Arabia': ['Riyadh', '36 Million', 'Middle East'],
#  'Japan': ['Tokyo', '125 Million', 'East Asia'],
#  'United Kingdom': ['London', '67 Million', 'Europe'],
#  'Canada': ['Ottawa', '40 Million', 'North America'],
#  'Egypt': ['Cairo', '112 Million', 'Africa'],
#  'Brazil': ['Brasilia', '215 Million', 'South America'],
#  'Australia': ['Canberra', '26 Million', 'Oceania']}
