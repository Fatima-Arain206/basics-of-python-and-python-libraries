# %% [markdown]
# lets make a dictionary and then convert it into data frame

# %%
dict_data ={
    'name': ['Fatima','ali','Zeeshan','shayan'],
    'age':  [21,25,26,45],
    'city': ['Badin','HYBD','Lahore','dubai']
}
dict_data
# Out:
# {'name': ['Fatima', 'ali', 'Zeeshan', 'shayan'],
#  'age': [21, 25, 26, 45],
#  'city': ['Badin', 'HYBD', 'Lahore', 'dubai']}

# %%
# convert it into data frame

import pandas as pd
import numpy as np
data_frame = pd.DataFrame(dict_data,  )
# data_frame.astype(np.int32)

# %%
print(data_frame['age'].dtype)# this happen because there is a null value pandas can not handle intgert null 
# thats why it change int into float 64 it is easy handle for null values
# Out:
# int64

# %%
print(data_frame['age'].unique())
# Out:
# [21 25 26 45]
