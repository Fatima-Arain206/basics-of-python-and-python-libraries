# %% [markdown]
# lets know the difference between the loc and iloc ## indexers

# %%
import pandas as pd

df = pd.read_csv(r"D:\sql_ultimate\sql-ultimate-course-main\datasets\OrdersArchive.csv",encoding='utf-8')

df
# Out:
#    OrderID  ProductID  CustomerID  SalesPersonID   OrderDate    ShipDate  \
# 0        1        101           2              3  2024-04-01  2024-04-05
# 1        2        102           3              3  2024-04-05  2024-04-10
# 2        3        101           1              4  2024-04-10  2024-04-25
# 3        4        105           1              3  2024-04-20  2024-04-25
# 4        4        105           1              3  2024-04-20  2024-04-25
# 5        5        104           2              5  2024-05-01  2024-05-05
# 6        6        104           3              5  2024-05-05  2024-05-10
# 7        6        104           3              5  2024-05-05  2024-05-10
# 8        6        101           3              5  2024-05-05  2024-05-10
# 9        7        102           3              5  2024-06-15  2024-06-20
#
#   OrderStatus       ShipAddress     BillAddress  Quantity  Sales  \
# 0     Shipped       123 Main St  456 Billing St         1     10
# ...

# %%
# print row 5 
# the loc function works on labels the number of row is like a name of row it can a string also

# print(df.loc[0])
# just print sales 
# print(df.loc[0,'Sales']) # the row and the column name
# print(df.loc['Sales'])

# %%
# ## iloc  it is also return a row but it works on positions

# # df.iloc[7]
# df.iloc['Sales']# only index position
## want to check row 6's order_status
# for iloc function give the column positon number
df.iloc[6,6]
# Out:
# 'Delivered'

# %%
# check head
# df.head(5)# top 5
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        10 non-null     int64
#  1   ProductID      10 non-null     int64
#  2   CustomerID     10 non-null     int64
#  3   SalesPersonID  10 non-null     int64
#  4   OrderDate      10 non-null     str
#  5   ShipDate       10 non-null     str
#  6   OrderStatus    10 non-null     str
#  7   ShipAddress    10 non-null     str
#  8   BillAddress    7 non-null      str
#  9   Quantity       10 non-null     int64
#  10  Sales          10 non-null     int64
#  11  CreationTime   10 non-null     str
# dtypes: int64(6), str(6)
# memory usage: 1.1 KB

# %%
df['Sales']
# Out:
# 0    10
# 1    15
# 2    20
# 3    60
# 4    60
# 5    25
# 6    50
# 7    50
# 8    50
# 9    60
# Name: Sales, dtype: int64

# %%
# access whole col throiugh loc
df.loc[:,'Sales',]
# Out:
# 0    10
# 1    15
# 2    20
# 3    60
# 4    60
# 5    25
# 6    50
# 7    50
# 8    50
# 9    60
# Name: Sales, dtype: int64

# %%
df[['Sales','CustomerID']]
# Out:
#    Sales  CustomerID
# 0     10           2
# 1     15           3
# 2     20           1
# 3     60           1
# 4     60           1
# 5     25           2
# 6     50           3
# 7     50           3
# 8     50           3
# 9     60           3

# %%
df.loc[6, ['Sales',"CustomerID"]]
# Out:
# Sales         50
# CustomerID     3
# Name: 6, dtype: int64
