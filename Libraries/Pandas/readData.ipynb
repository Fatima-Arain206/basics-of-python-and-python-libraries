# %%
# lets use a pandas function read.csv

import pandas as pd

# give pad
fd= pd.read_csv('Customers.csv',encoding='utf_8')
# loaded successfully 
# print
# print(fd,end='  ')
fd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  5 non-null      int64
#  1   FirstName   5 non-null      str
#  2   LastName    5 non-null      str
#  3   Country     5 non-null      str
#  4   Score       5 non-null      int64
# dtypes: int64(2), str(3)
# memory usage: 332.0 bytes

# %% [markdown]
# read data from csv file

# %%
import numpy as np
# np.mean(fd['Score'])
# fd['CustomerID'].mean()
np.mean(fd['CustomerID'])
# Out:
# np.float64(3.0)

# %%
print(fd['FirstName'])
# Out:
# 0               Jossef
# 1                Kevin
# 2                 Mary
# 3                 Mark
# 4                 Anna
# Name: FirstName, dtype: str

# %%
np.mean(fd['Score'])
# Out:
# np.float64(678.0)
