# %%
# lets use a pandas function read.csv

import pandas as pd

# give pad
fd= pd.read_csv('Customers.csv',encoding='utf_8')
# loaded successfully 
# print
# print(fd,end='  ')
fd
# Out:
#    CustomerID            FirstName         LastName             Country  \
# 0           1               Jossef         Goldberg             Germany
# 1           2                Kevin            Brown                 USA
# 2           3                 Mary                                  USA
# 3           4                 Mark                              Germany
# 4           5                 Anna            Adams                 USA
#
#       Score
# 0     350.0
# 1     900.0
# 2     750.0
# 3     500.0
# 4       NaN

# %% [markdown]
# read data from csv file
