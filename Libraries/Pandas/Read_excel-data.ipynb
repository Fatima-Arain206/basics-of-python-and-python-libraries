# %%
import pandas as pd
data_ex = pd.read_excel(r'Dict_Frame_into_excel.xlsx')

# %%
data_ex
# Out:
#    Unnamed: 0    name  age       city  roll_num  gpa department  semester  \
# 0           0  Fatima   20    Karachi       101  3.8         CS         4
# 1           1     Ali   22     Lahore       102  3.5         SE         6
# 2           2  Ayesha   21  Islamabad       103  3.9         CS         4
# 3           3    Zain   23      Badin       104  3.2         IT         8
#
#    is_graduated
# 0         False
# 1         False
# 2         False
# 3          True
