# %%
import pandas as pd
chunk= pd.read_csv(r"D:\sql_ultimate\sql-ultimate-course-main\datasets\orders.csv",chunksize=4, encoding='utf-8')

chunk

# %%
# ?print the chunks
for ch in chunk:
    print(ch.shape)
# Out:
# (4, 12)
# (4, 12)
# (2, 12)

# %%
# lets filter ProductID  CustomerID ShipAddress BillAddress
small_data_frame=[]
for ch in chunk:
    small_data_frame.append(ch[['ProductID','CustomerID','ShipAddress']])

# %%
small_data_frame
# Out:
# []

# %%
# try again
import pandas as pd
chunk= pd.read_csv(r"D:\sql_ultimate\sql-ultimate-course-main\datasets\orders.csv",chunksize=4, encoding='utf-8')

small_data_frame=[]
for ch in chunk:
    small_data_frame.append(ch[['ProductID','CustomerID','ShipAddress']])
small_data_frame
# Out:
# [   ProductID  CustomerID         ShipAddress
#  0        101           2  9833 Mt. Dias Blv.
#  1        102           3      250 Race Court
#  2        101           1        8157 W. Book
#  3        105           1   5724 Victory Lane,
#     ProductID  CustomerID       ShipAddress
#  4        104           2               NaN
#  5        104           3  1792 Belmont Rd.
#  6        102           1  136 Balboa Court
#  7        101           4    2947 Vine Lane,
#     ProductID  CustomerID    ShipAddress
#  8        101           2  3768 Door Way
#  9        102           3            NaN]
