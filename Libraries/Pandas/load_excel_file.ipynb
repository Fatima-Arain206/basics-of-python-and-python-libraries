# %% [markdown]
# lets try to load an excel file

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# load excel use pd.read_excel

exl= pd.read_excel(r"D:\sql_ultimate\sql-ultimate-course-main\datasets\Products.xlsx")

# %%
# print(exl)
# want to see with line
exl
# Out:
#    ProductID Product     Category  Price
# 0        101  Bottle  Accessories     10
# 1        102    Tire  Accessories     15
# 2        103   Socks     Clothing     20
# 3        104    Caps     Clothing     25
# 4        105  Gloves     Clothing     30
