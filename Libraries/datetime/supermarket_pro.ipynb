# %% [markdown]
# the problem is that find the high cell day and good rating day of super market

# %%
# important libs to use
import pandas as pd
import matplotlib.pyplot as pt
import datetime as dt
import seaborn as sb

# %%
# load data 
data_f1=pd.read_csv(r"D:\data_analytic\reading pdf\archive (1)\annex1.csv")
data_f2 = pd.read_csv(r"D:\data_analytic\reading pdf\archive (1)\annex2.csv")

data_f3 = pd.read_csv(r"D:\data_analytic\reading pdf\archive (1)\annex3.csv")
data_f4 = pd.read_csv(r"D:\data_analytic\reading pdf\archive (1)\annex4.csv",encoding='utf-8')

# %%
data_f2.info()

# data_f2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 878503 entries, 0 to 878502
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Date                         878503 non-null  datetime64[us]
#  1   Time                         878503 non-null  str
#  2   Item Code                    878503 non-null  int64
#  3   Quantity Sold (kilo)         878503 non-null  float64
#  4   Unit Selling Price (RMB/kg)  878503 non-null  float64
#  5   Sale or Return               878503 non-null  str
#  6   Discount (Yes/No)            878503 non-null  str
#  7   Day_of_week                  878503 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), str(4)
# memory usage: 53.6 MB

# %%
data_f2.head(4)
# Out:
#          Date          Time        Item Code  Quantity Sold (kilo)  \
# 0  2020-07-01  09:15:07.924  102900005117056                 0.396
# 1  2020-07-01  09:17:27.295  102900005115960                 0.849
# 2  2020-07-01  09:17:33.905  102900005117056                 0.409
# 3  2020-07-01  09:19:45.450  102900005115823                 0.421
#
#    Unit Selling Price (RMB/kg) Sale or Return Discount (Yes/No)
# 0                          7.6           sale                No
# 1                          3.2           sale                No
# 2                          7.6           sale                No
# 3                         10.0           sale                No

# %%
# step 1 datetime tracking change the txt formet date time data into actual datetime type
data_f2['Date'] = pd.to_datetime(data_f2["Date"])

# %%
# confirm it
# data_f2.info()
data_f2['Date'].head()
# Out:
# 0   2020-07-01
# 1   2020-07-01
# 2   2020-07-01
# 3   2020-07-01
# 4   2020-07-01
# Name: Date, dtype: datetime64[us]

# %%
# add a new column with days name
data_f2['Day_of_week']=  data_f2['Date'].dt.day_name() # type: ignore

# %%
data_f2.tail(4)
# Out:
#              Date          Time        Item Code  Quantity Sold (kilo)  \
# 878499 2023-06-30  21:35:14.358  102900011022764                 0.669
# 878500 2023-06-30  21:35:20.264  102900005115250                 0.125
# 878501 2023-06-30  21:35:21.509  102900011016701                 0.252
# 878502 2023-06-30  21:40:48.248  102900011022764                 0.803
#
#         Unit Selling Price (RMB/kg) Sale or Return Discount (Yes/No)  \
# 878499                         12.0           sale                No
# 878500                         24.0           sale                No
# 878501                          5.2           sale                No
# 878502                         12.0           sale                No
#
#        Day_of_week
# 878499      Friday
# 878500      Friday
# 878501      Friday
# 878502      Friday

# %%
# aggregation find the average of total sales accordng to days
# data_f2.groupby(['Day_of_week'])['']

# %%
# merge the data 
extract_from_df3= data_f3[['Item Code','Wholesale Price (RMB/kg)']]
extract_from_df3.head()
extract_from_df2 = data_f2[['Item Code','Day_of_week','Date']]

# %%
# merge it with df2
new_data = pd.merge(extract_from_df2 , extract_from_df3, on='Item Code') ????
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[34], line 2
#       1 # merge it with df2
# ----> 2 new_data = pd.merge(extract_from_df2 , extract_from_df3, on='Item Code')
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:399, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     384 else:
#     385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#    (...)    397         validate=validate,
#     398     )
# --> 399     return op.get_result()
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1141, in _MergeOperation.get_result(self)
#    1138 if self.indicator:
#    1139     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# -> 1141 join_index, left_indexer, right_indexer = self._get_join_info()
#    1143 result = self._reindex_and_concat(join_index, left_indexer, right_indexer)
#    1145 if self.indicator:
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1423, in _MergeOperation._get_join_info(self)
#    1419     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1420         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1421     )
#    1422 else:
# -> 1423     (left_indexer, right_indexer) = self._get_join_indexers()
#    1425     if self.right_index:
#    1426         if len(self.left) > 0:
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1397, in _MergeOperation._get_join_indexers(self)
#    1395 # make mypy happy
#    1396 assert self.how != "asof"
# -> 1397 return get_join_indexers(
#    1398     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1399 )
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:2110, in get_join_indexers(left_keys, right_keys, sort, how)
#    2108     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    2109 else:
# -> 2110     lidx, ridx = get_join_indexers_non_unique(
#    2111         left._values, right._values, sort, how
#    2112     )
#    2114 if lidx is not None and is_range_indexer(lidx, len(left)):
#    2115     lidx = None
#
# File c:\Users\fatima28\Desktop\ML\.venv\Lib\site-packages\pandas\core\reshape\merge.py:2153, in get_join_indexers_non_unique(left, right, sort, how)
#    2151     ridx, lidx = libjoin.left_outer_join(rkey, lkey, count, sort=sort)
#    2152 elif how == "inner":
# -> 2153     lidx, ridx = libjoin.inner_join(lkey, rkey, count, sort=sort)
#    2154 elif how == "outer":
#    2155     lidx, ridx = libjoin.full_outer_join(lkey, rkey, count)
#
# File pandas/_libs/join.pyx:47, in pandas._libs.join.inner_join()
# ---> 47 'Could not get source, probably due dynamically evaluated source code.'
#
# MemoryError: Unable to allocate 4.50 GiB for an array with shape (603915514,) and data type int64
