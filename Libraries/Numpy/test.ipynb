# %%
#list 
import sys
p_list = [1,2,3,4,5,5,6,7]
print(p_list)
print(f'size  {sys.getsizeof(p_list)} actual storage of {len(p_list*28)}')
# numpy array
import numpy as np
p_arr = np.array([1,2,3,4,5,6,7])
print(p_arr)
print(f'size {sys.getsizeof(p_arr)}')
print(p_arr.shape)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7]
# size  120 actual storage of 224
# [1 2 3 4 5 6 7]
# size 168
# (7,)
