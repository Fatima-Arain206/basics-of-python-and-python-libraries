# %%
import numpy as np
arr = np.arange(0,10,2)
print(arr)
print(type(arr))
# Out:
# [0 2 4 6 8]
# <class 'numpy.ndarray'>

# %%
arl = list(range(1,10,1))
print(arl)
print(type(arl))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# <class 'list'>
