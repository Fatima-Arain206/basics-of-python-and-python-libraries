# %%
import numpy as np
d1 = np.array([1,2,3,4,5,6,7])
print(d1)
# Out:
# [1 2 3 4 5 6 7]

# %%
# 2D
d2 = np.array([[1,2,3,'f'],
               [4,5,6,'a'],
               [7,8,9,'t']])
d2
print(d2[1][3]*2)
d2.dtype
# Out:
# aa
# dtype('<U21')

# %%
# change the type
print(d2.dtype)
d=d2.astype(str)
d
# Out:
# <U21
# array([['1', '2', '3', 'f'],
#        ['4', '5', '6', 'a'],
#        ['7', '8', '9', 't']], dtype='<U21')

# %%
print(d2[1][2]+2)

# %%
a=np.array([1,2,3,4])
a.dtype
a
a.astype(int)
a.dtype
a
# Out:
# array([1, 2, 3, 4])
