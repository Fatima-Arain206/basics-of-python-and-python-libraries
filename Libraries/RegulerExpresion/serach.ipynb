# %% [markdown]
# the re libray is famous for search

# %%
import re
string="My name is fatima arain 234 dkgaj"
result=re.search("name",string)
print(result)
if result:
    print("match")
else:
    print("not match")
# Out:
# <re.Match object; span=(3, 7), match='name'>
# match

# %%
log_data="the application started suucesffuy ion"
match=re.search(r'[ti]on',log_data)
if match:
    print("location ",match.span())# this will show index starting to end
    print("match Text ",match.group())# this will show excat matched text
# Out:
# location  (12, 15)
# match Text  ion

# %% [markdown]
# r"pattren"
# this is a raw string ignoring slashes like \n \s
#
# ## [ti]on this will comapare both of them ineer brackets if one of them match it will return
#
# re.seearch scan left to right , returns first match
#
# ## this library only works on strings

# %%
# to find all matching elements we use re.findll() it returns a lsit

st=""" my name is fat fatima fatimaarain"""
find=re.findall(r"a",st)
print(find)

data='datbase error 404 occured.then network error 502 and time out error 404'
#/d+ is for didgit srch

err=re.findall(r"\d+",data)
err
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# ['404', '502', '404']

# %%
#re.sub it search all and replce them
my_phoneNum="3-892-8571-871hj-891fhjKFKKKS"
replace=re.sub(r"\d",'X',my_phoneNum)
replace

rp=re.sub(r"X","NOO",replace)
rp
# Out:
# 'NOO-NOONOONOO-NOONOONOONOO-NOONOONOOhj-NOONOONOOfhjKFKKKS'

# %%
#re.split it breaks the string according to pattern ,while normla string.split() break the str ,following a char
know="python,java:c++,html ;css,sql/"
# i want oto break this with , : ; and space \s
lang=re.split(r'[,\s;:]',know)
lang
ang=re.split(r'[,]',know)
ang
# Out:
# ['python', 'java:c++', 'html ;css', 'sql/']
