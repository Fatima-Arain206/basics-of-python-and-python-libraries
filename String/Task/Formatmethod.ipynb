# %%
name="fatima"
n=2
print("hi {} your lucky numer is {}".format(name,n ))
print("hi {namee} your lucky number is {num}".format(namee=name,num=n))

def cel(x):
    return (x-32)*5/9
for o in range(0,101,10):
    print("F{:>13} | {:>6.2f} c".format(o,cel(o)))

# %%
x="values"
y=90
print('''String formatting lets you insert {} into strings.
They can even be numbers, like {}.'''.format(x, y))

# %%
var_a = 'A'
var_b = 'B'
print('{1}, {0}'.format(var_a, var_b))
print('{0}, {1}'.format(var_a, var_b))

# %% [markdown]
# plit the string at the first occurrence of sep , and return a 3-tuple containing the part before the separator, the separator itself, and the part after the separator. If the separator is not found, return a 3-tuple containing the string itself, followed by two empty strings.

# %%
my_string = 'https://www.google.com/'

my_string.partition('.')

# %% [markdown]
# his example returns a match object that contains information about the search. In this case, it tells you that the substring ‘wall’ does occur in the string from indices 18–22.
#
# Regex is especially useful because it allows you a very high degree of customization when performing your searches.

# %%
import re

my_string = 'Three sad tigers swallowed wheat in a wheat field'

re.search('wall', my_string)

# %%
import re

my_string = 'Three sad tigers swallowed wheat in a wheat field they were mad'

sub=re.search('[bms]ad', my_string)

# sub=re.search('[wh]at',my_string)
print(sub)
