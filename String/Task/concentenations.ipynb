# %%
def deleting_first_char_and_concatenate():
    a = input(" enter a string")
    b = input(" enter a string")
    if len(a)==0 and len(b) == 0:
        print(" both are empty")
        return -1
    elif len(a)==0 or len(b) == 0:
        print("both stings should have something ")
        return 1
    else:
        # working process
        newst = a[1:] + b[1:]
        print(newst)
        return newst

deleting_first_char_and_concatenate()
# Out:
# atimarain
# 'atimarain'
