# %%
a="fatima"
print(id(a))
a=a+"arain"
print(id(a))
# Out:
# 2817840357232
# 2817840354928

# %%
b='"my name is fatima"'
b
print(b)
# Out:
# "my name is fatima"

# %%
c="\" my favrovte drmaa is ger's\""
print(c)
c[1:9]
# Out:
# " my favrovte drmaa is ger's"
# ' my favr'
