# %%
def cap_sent(sent):

    capi= ""
    i=0
    while i < len(sent)-1:
        if i ==0:
           capi = sent[i]
           capi = capi.upper()
        #
        # elif sent[i]+sent[i+1] == ' 'and ( 'it' or sent[i] == 'is' or sent[i]=="or" or sent[i] == 'a' or sent[i] == 'are' or sent[i] == 'an') :
        #     capi = capi + sent[i]

        elif sent[i]==' ':
                capi = capi + sent[i]
                k = sent[i+1]
                k= k.upper()
                capi = capi+k
                i = i+2
                print()
                continue



        else:

            capi = capi + sent[i]
        i = i+1

    return capi

sent = input(" enter a sentence ")
print(f"your typed sentence was { sent}")
cap = cap_sent(sent)
if len(sent) ==0:
        print("empty ")

else:
    print(f"your typed sentence was { sent}")
    print(f" after capitalization { cap }")
# Out:
# your typed sentence was my name is
#
#
# your typed sentence was my name is
#  after capitalization My Name I
