# %% [markdown]
# compare a string and like st = "aabbbbcccdddeeessss"
# return a new string
# a2b4c3d3e3s4

# %%
def comp(st):
    if len(st) ==0:
        return -1
    elif len(st)==1:
        return 1
    else:
        visit =[]
        comp = ''
        count =1
        for i in range(len(st)-1):
            if st[i] == st[i+1]:
                count +=1
                visit.append(st[i])
            elif st[i] != st[i+1]:
                comp = comp+st[i]+str(count)
                count=1
        if count >= 1:
            comp = comp+ st[-1]+str(count)
        return comp

print(comp("fatima"))
# Out:
# f1a1t1i1m1a1
