# %% [markdown]
# remove all special characters and punctuations

# %%
def simple_string(st):
    if len(st) ==0:
        return -1
    simple =''
    i =0
    while i < len(st):
        if st[i] ==',' or st[i] =="'" or st[i] =='?'  or st[i] =='.':
            i = i+1
            continue
        elif not st[i].isalpha():
             i = i+1
             continue
        elif st[i].isdigit ():

            i = i+1
        else:
            simple = simple + st[i]


        i = i+1
    print(simple)
    return simple


st = input("enter anything")
print(f"your input { st}")
print(f" final{simple_string(st)}" )
# Out:
# your input f@t!?ma 78*()_
# ftma
#  finalftma
