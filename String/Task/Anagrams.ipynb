# %% [raw]
# check if both strings a anagram
# it means string a has all char i b string  no matter what is the oredr example
# listen silent
# c

# %%
def anagram(a,b):
    if len(a) ==0 or len(b )==0:
        print(f"both string should have somthing")
    visit=[]
    anagram = True
    for i in a:
        #for j in b:
        if i in b :
            break
        else:
            anagram = False





    return anagram

a = input(" enter a string")
b = input(" enter a string ")
# print(anagram(a,b))
print(f" yes it is anagram " if anagram(a,b) else " not anagram")
# Out:
#  yes it is anagram

# %%
a= "fatima"
print(a[::-1])
l = [10,20,30]
print(l
      [::-1])# {start stop step t} this is the formula work behind start is 0 stop is till last and step is -1 means list will flow right to left
# Out:
# amitaf
# [30, 20, 10]

# %%
def create_profile(username: str, age: int) -> str:
    return f"User {username} is {age} years old."
print (create_profile("fatima",22))
# Out:
# User fatima is 22 years old.
