# %% [markdown]
# indexing are accessing elements of a sequence using [] using indexing operations [start: end : step]

# %%
name = "411023478"

# print(name[-1])
# -1 show the ending side of string it will show law index
# #print(name[-2])# = 7


# ------
## now check the positive side
# print(name[0])# the 0 index

# ------
# now use the formula [start : end]
# print(name[0:-1])# it will start from 0 and end at minus 1 remember it will not include the end point

# ------
# another example
# print(name[-1:]) # after colon if you write nothing it mean till end in this case it will print 8 b/c it is last index

# ------
# once more
# print(name[0:])# it means 0 to end point it will print the whole str
#
# print(name[0:5])# it will print five 5 elements 0 t0 4 note on index 5 will not count

# ------
#  another example
# print(name[0:100])# this is slicing magic python will return only string length not any error

# .>>>>>>>>>>>
# print(name[50:100])# this will not give any error but return an empty str ""

#  now the [start end step formula

# print(name[0:4:2])# this formula mostly works in loops  it is like iteration this will return on step here we give space 2 it returns 41 in 4110 1 is 2 steps for from 0 index


# ........
# print(name[0::2])# this simple mean end at end😂😁 and step by two

# print(name[:-2:3]) #start from 0 end at end step by 3
# print(name[0:4])# default inc by 1
# print(name[0:4:2])
# print(name[:5])# defeat start 0 step 1
#  this is called inclusive and exclusive

# print(name[4:7])


# print(name[::-1])# use for reverse
# print(name[-1::-1])
# how the both works these are same when python see start and end are default and step is negative it sets start to negative the start is last index same as the next statement[-1::-1] in these cases python f"low right to lef"t
# last index is 10 step 1 10 -1 > 9-1 >8 -1
a = ("fatima")
# print(a[4:1:-1])#mit
#
# print(a[-1:-4:-1])#ami

# print(a[1:4:-1])# empty string b/c direction is wrong it
#start from 1end to 4 but stp is -1
#  when start < end step will possitive
# start > end step will be negative
print(a[4::-1])
# Out:
# mitaf
