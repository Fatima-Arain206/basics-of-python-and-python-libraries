# %%
# print("your name should be less than or equal to 12 char ")
# print("your name should not contain spaces and digits")
name = input("Enter your name ")
if len(name) > 12   :
    print(f"the name length is to long it is contain more 12 char {len(name)}")
elif not name.find(' ') == -1 :
    print("do not add spaces in name ")
elif not name.isalpha():
    print("your name is containing digits ")

else:
    print("this is a valid name")
# Out:
# your name is containing digits
