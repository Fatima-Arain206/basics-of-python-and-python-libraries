# %%
# f=open("readfile.ipynb")
f=open('qoute.txt')
for i in f:
    print(i.strip())
f.close()
# if you did not use "with" then use close
# Out:
# "Goodbyes are only for those who love with their eyes.
#
# Because for those who love with heart and soul there is no such thing as separation."
#
# Rumi. Sympathy, Death, True Love.
#
# Always remember you are braver than you believe, stronger than you seem, smarter than you think and twice as beautiful as you'd ever imagined. Yesterday I was clever, so I wanted to change the world.
#
# The Inspiration You Seek. Is Already Within You. Be Silent And Listen. Rumi. Inspiration, Silent, Within You.
#
# A Candle never Loses any of its Light while Lighting up another candle. Rumi. Light, Lighting, Candle.
