# %%
driverOnline = True
isNearest = True
rating_point = 1.8
if driverOnline and isNearest and rating_point > 4.5:
    print(" available ride with a good rider 🚓🚓")
elif not driverOnline:
    print("can not book ride because driver is of line 😣😣")
elif not isNearest:
    print("driver is too far🚆⛵⛵🛰🛰")
elif  rating_point < 4.5:
    print(" the rating point of that driver is not enough 😴🥱")
# Out:
#  the rating point of that driver is not enough 😴🥱
