# %%
x=2
y = 9
y+=1
print((x>10) and (y  > 10))# false
# Out:
# False

# %% [markdown]
# =And

# %%
x = 10
y =30
print((x==10) or (y< 20))# true
# Out:
# True

# %% [markdown]
# or
# the ultimate mix

# %%
x = True
y =False
z = True
print (x and not y) or (y and z) and not(x or z)
# Out:
# True
# False

# %%
res = x  and y# output is y =False
print(res)
# Out:
# False

# %%
a =10
b = 20
c = 0
y = a and b # output is b 20
print(y)
z = a or b # output = 10
print(z)
w = a and c # output = c 0
print(w)
m = a or c # output is a =10
print(a)
# Out:
# 20
# 10
# 0
# 10
