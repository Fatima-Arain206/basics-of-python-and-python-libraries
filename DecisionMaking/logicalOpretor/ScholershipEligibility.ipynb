# %%
gpa = float(input("Enter your GPA ...."))
income = int(input("Enter family income "))
sQouta = input(" Are you special qouta (y/n)")
sQouta = sQouta.upper()
if sQouta == 'Y':
    sQouta = True
else:
    sQouta=False
if gpa >= 3.5 and sQouta  :
    print("You are eligible for this scholarship")
elif gpa >= 3.5 and  income < 50000  :
    print("not matter if you are not a specail quota ")
    print(" your GPA is still high and you are eligible ")
else:
    print('Not eligible')
# Out:
# Not eligible
