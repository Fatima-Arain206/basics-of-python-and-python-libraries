# %%
primeMember = False
userP = input("Are you a prime member (y/n) ")
userP = userP.upper()
if userP == "Y":
    primeMember = True
total_cart = int(input("Enter your total carts"))
if primeMember or total_cart > 2000 :
    print("Hello sir ☺  you got 30% discount 😱😱😱")
elif not primeMember:
    print(" sorry your are not prime member and not have enough carts")
# Out:
# Hello sir ☺  you got 30% discount 😱😱😱
