# %%
theory = int(input("Enter your theory marks "))
lab = int(input("enter your lab  marks "))
if theory >=40 and lab >=40:
    print("pass")
elif theory < 40 and lab > 40:
    print(" your theory score is not enough to pass")
elif theory > 40 and lab <40 :
    print(" your lab score is not enough to pass")
else:
    print("fail")
# Out:
#  your theory score is not enough to pass
