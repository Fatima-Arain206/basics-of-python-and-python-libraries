# %%
normalTemp = False
if not normalTemp:
    print(" teep teep \n temperature is not normal")
    print("temperature alert ")
else:
    print("temperature is normal")
# Out:
#  teep teep
#  temperature is not normal
# temperature alert

# %%
a= 10
b= 20
c = 30
print((a<b) and (b<c))#true
print((a>b) or (c > b))# true
print(not (a==b) and (c>b))# true
print((a+b==c) and (c-b != a ))# false
# Out:
# True
# True
# True
# False
