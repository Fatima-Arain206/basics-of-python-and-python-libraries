# %%
hasDegree = False
has3YearEx = False
userD = input(" Do you have a university degree of software engineering ( T/F)")
userEx = input(" Do you have  experiance more then 3 years of software engineering ( T/F)")
userD = userD.upper()
userEx = userEx.upper()
if userD == 'T' or userEx == "T":
    hasDegree = True
    has3YearEx = True
if  hasDegree or has3YearEx:
    print("Congratulations you are eligible for this job")
else:
    print(" you are not eligible")
# Out:
#  you are not eligible
