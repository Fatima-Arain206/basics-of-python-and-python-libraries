# %%
ticketP = False
vipPass = False
ticket = input(" Sir , do you purchase movie ticket(y/n) ??")
pas = input("  do you have any vip pass(y/n) ??")
ticket = ticket.upper()
pas = pas.upper()
if ticket == 'Y':
    ticketP = True
if pas =='Y':
    vipPass = True

if ticketP or vipPass:
    print(" please  enjoy your  movie ....")
else:
    print("Kindly buy a ticket")
# Out:
#  please  enjoy your  movie ....
