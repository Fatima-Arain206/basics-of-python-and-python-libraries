# %%
storage = 500
current = 300
isFull = False
sizeF = int(input("Enter your file size "))
if sizeF >= storage or current == storage:
    print(" File size is  large can't move to folder not have much space")
elif (current + sizeF) == 480 or (current + sizeF)== storage:
    print(" storage is full manage storage")

else:
    print("you can move your file to this folder")
# Out:
# you can move your file to this folder
