# %%
order = input(" would you like some food (y/n)")
givenOrder = False
if order == 'y':
    givenOrder =  True

if givenOrder:
    print("here are the available foods ")
    print(f" pizza" , 'pasta' , 'zinger' ,'burger', 'chicken' ,
     "custer , biryani , salad , 'chinese'" )
else:
    print("okk")
# Out:
# okk
