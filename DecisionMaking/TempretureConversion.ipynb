# %%
unit= input("Is this temperature in Celsius or Fahrenheit (C/F)")
unit = unit.upper()

temp = float(input(" Enter the temperature"))
if unit == "C":
    #pass
# c * 9/5+32
     temp = round(( (temp * 9)/5) + 32,1)
     print(f" temperature in F :{ temp}")
elif unit == 'F':
      #pass
      temp = round(((temp-32) * 5 )/ 9,1)
      print(f" temperature in C :{ temp}")




else:
    print(f"{unit }is invalid unit temperature measurement")
# Out:
#  temperature in C :33.0

# %% [markdown]
# temperature conversion

# %% [markdown]
# pass means do nothing it is a placeholder which states that currently do nothing but the future work will be do here
