# %%
num = 4
print("positive " if num> 0 else "negative")
# Out:
# positive

# %% [markdown]
# conditional  expressions A one line short-cut for the if else statement (ternary op ) print or assign one of two values based on a condition
# x if condition else y

# %%
res = "even"if num %2== 0  else " odd"
print(res)
# Out:
# even

# %%
a = 9
b =7
maximum = f"max is {a}"if a > b else f"max is {b}"
print(maximum)
# Out:
# max is 9

# %%
min = a if a<b else b
print(min)
# Out:
# 7

# %%
age =12
status ="adult" if age> 18 else "child"
print(status)
# Out:
# child

# %%
tem = 23
weather = "hot " if tem >25 else "cold"
print(weather)
# Out:
# cold
