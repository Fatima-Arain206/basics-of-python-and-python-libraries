# %%
import time
try:
    my_time=int(input("enter the time seconds"))
    for x in range(0,my_time):
        print(x)
        time.sleep(1)
except TypeError:
    print("enter value in integer")
except ValueError:
  print("you can  not skip this")
except KeyboardInterrupt  :
    print("just wait dont click it")
else:
    print('get up')# this will print after 10 seconds
# Out:
# 0
# 1
# 2
# get up
