# %%
# A = p(1+r/n)**
try:
    principle =0
    time =0
    rate =0
    while True :
        principle= float(input(f" Enter the principle amount:"))
        if principle<0:
            print("principle can not be less then 0 ")
        else:
            break
    while True:
        rate = float(input("Enter interrest rate "))
        if rate <0:
            print(f" interest can not b less then 0  ")
        else:
            break

    while True:
        time = int(input("Enter in years "))
        if time <0:
            print(f" time can not b less then 0  ")
        else:
            break
    total_amount= principle * (( 1+ rate / 100)**time)


except TypeError:
    print(f" enter correct Value")
except ValueError:
    print(f" you cant skip")
print(principle)
print(rate)
print(time)
print(f" your total amount is { total_amount :.2f}")
# Out:
#  you cant skip
# 0
# 0
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 35
#      31     print(f" you cant skip")
#      32 print(principle)
#      33 print(rate)
#      34 print(time)
# ---> 35 print(f" your total amount is { total_amount :.2f}")
#
# NameError: name 'total_amount' is not defined
