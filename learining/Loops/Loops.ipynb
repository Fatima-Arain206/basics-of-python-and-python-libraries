# %%
# while loop = execute come thing while condition remains true

# %%
name= input("enter your name")
while name=='':
    name= input("enter your name")
print(name)

# %%
age= int(input("age enter"))
while age<0:
    age = int(input(age))
    print(f"uou are {age} years old")

# %%
try :
    age=int(input("enter your age"))
    while age < 0:
        age= int(input(" enter your age again"))
except TypeError:
    print(f"invalid type")
except ValueError:
    print(f"value error")
else:
    print(f"you are {age } years old")

# %%
food=input("enter your fav food name or (q to quite)")
while not food=="q":
    print(f"you like {food}")
    food=input("enter another your fav food name or (q to quite)")
print("bye😥😥😥")
# Out:
# you like biryani
# you like qorma
# you like larela
# you like macroni
# you like pizza
# you like bueger
# bye😥😥😥

# %%
#use or
try :
    num = int(input(" enter a number (1 - 10)"))
    while num < 1 or num >10:
        print(f"{num} is not valid  number ")
        num = int(input(" enter a number again (1-10)"))
except ValueError:
    print(f" Value Error ..")
except TypeError:
    print(f" Type Error ")
else :
    print(f" your number is {num}")
# Out:
# 90 is not valid  number
# 67 is not valid  number
# -90 is not valid  number
# 45 is not valid  number
# 111 is not valid  number
#  your number is 1
