# %%
sq= int(input("enter length of square"
              ""))
sy=input("enter a symbol for square")

for x in range(sq):
    for y in range(sq):
        print(sy+' ',end='')
    print()
# Out:
# . . . .
# . . . .
# . . . .
# . . . .
