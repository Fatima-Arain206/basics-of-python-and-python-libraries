# %%
from datetime import datetime

from prompt_toolkit.key_binding.bindings.named_commands import uppercase_word
from pygments.lexers import data

#1
pr = 2450.5 # print 2,450.50
print(f"Rs {pr:,.2f}")

# %%
#2 right alignment 10 char
st1 = "python"
st2="java"
st3="c++"
print(f"{st1:>10}\n{st2:>10}\n{st3:>10}")

# %%
#3 center 20 char
c = "Student Report"
print(f".{c:^20}.")

# %%
#4 0 padding
print(f"{5:05}")

# %%
#6 percentage
n= 0.896

print(f" {n:.2f } ")

# %%
#6  binary conversion
a=98
print(f"{a:b}")

# %%
#7 convert hexadecimal to upper case

a=(f"{255: x}")
a=a.upper()
print(a)

# %%
#8 scientific notation
a=0.000246
print(f"{a:e}")

# %%
#9 comma
n=1000000000
print(f"{n:+,}")

# %%
#11 name and marks left and right align
name="fatima"
marks = 1550
print(f"{name:<10}={marks:>5}")

# %%
#12 character padding
h="hello word"
print(f"{h:*10}")

# %%
#13 date formet

print(f"{datetime.now(6,)}")

# %%
#14 expression
a='15'
b="12"
print(f"{int(a)*int(b)}")
print(f"{int(15*12)}")

# %%
#15
print(f"{1/3:.3f}")

# %%
#16 octal rep
oc=100
print(f"{oc:o}")

# %%
s="Programming is fun"
print(f"{s[:5]}")

# %%
#18 print{}
print("yes i can print this{1,3,4...90} numbers")

# %%
#19 combined formeting
a=89
print(f'{a:^10.2f}')

# %%
#20 name debugging
X=10
print(f"x=10")
