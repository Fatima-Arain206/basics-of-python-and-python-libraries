# %%
a=[1,3,4,6,7]
b=['a','b','c']
D=[3,5,6,89,]
a+b
c=a+D
c
# Out:
# [1, 3, 4, 6, 7, 3, 5, 6, 89]

# %%
a*2 # replication
print(len(b))
b*3# this value will not store
print(len(b*3))
# print(b[-2])
# Out:
# 3
# 9

# %%
b.count('a')
# Out:
# 1
