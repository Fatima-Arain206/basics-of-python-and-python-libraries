# %%
# find the hypotenuse of right triangle
# c  = a sq + b sq hole under root
import math
a = float(input(" enter length a "))
b = float(input(" enter width b "))
c = math.sqrt((pow(a,2)+pow(b,2)))
print(f" hypotenuse is {round(c,2)}")
# Out:
#  hypotenuse is 34.06
