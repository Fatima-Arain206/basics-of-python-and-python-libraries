# %%
a=[45,78,'f',45,8,8,32,54,5]
a.append(8)
'''this method only one element at the end'''
a.insert(3,9090)#this will add on perticluer pos

a.remove(45)# remove first finded
a
a.pop(3)# index base

a
# Out:
# [78, 'f', 9090, 8, 8, 32, 54, 5, 8]

# %%
#list method
b=['mango','banana','apple','cherry']
print(b)
#
empty=list()
empty.append(1)
empty.append(2)
empty.append(11)
empty.append(14)
empty.append(1)
empty
# Out:
# ['mango', 'banana', 'apple', 'cherry']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       8 empty.append(11)
#       9 empty.append(14)
#      10 empty.append(1)
#      11 empty
# ---> 12 d=list(2,3,5,6,87,)
#
# TypeError: list expected at most 1 argument, got 5
