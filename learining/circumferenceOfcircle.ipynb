# %% [markdown]
# calculate the circumference of circle using builtin func
# formula is
# c = 2pir

# %%
import math 
radius = float(input("enter radius "))
cer = 2*math.pi*radius
print(f"circumference of square is {round(cer,4)} cm ")
# Out:
# circumference of square is 76.0894
