# %% [markdown]
# madlibs is a game
#  word game where you create a story
#  by filling the blanks with random words

# %%
noun1 = input(" a name person or thing")
adjective1 = input(" enter a description of any thing")
adjective2 = input(" enter a description of any thing")
adjective3 = input(" enter a description of any thing")
verb = input(" enter a verb with ing")
adjective4 = input(" enter a description of any thing")

print(f"Today i learn {noun1}")
print(f" {noun1} is really {adjective1} and {adjective2}")
print(f"but i am {adjective3} to learn this")
print(f" i would {verb} to something new ")
print(f"like {adjective4}")
