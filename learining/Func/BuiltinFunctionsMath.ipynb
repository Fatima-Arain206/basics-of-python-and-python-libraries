# %%
a = 3.14
y =4
z =5
# round function

b = round(a)
print(a)
x=4.567893
c = round(x,3) # will round only three digits after . x =
print(c)
# Out:
# 3.14
# 4.568

# %%
#power function
print(y)
res = pow(y,3) # y power three 5 power three 
print(res)
# Out:
# 4
# 64

# %%
# absolute func
d = -2
print(abs(d))
# Out:
# 2

# %%
my = max(a,y,z)
print(my)
# Out:
# 5

# %%
mini = min(x,y,z)
print(mini)
# Out:
# 4
