# %%
# calculate the area of circle
# area = pi * r**
import math
radius = float(input("Enter radius "))
#area = math.pi * math.pow(radius,2)
area = math.pi * radius**2
print(f"Area of circle is { round(area,2) }")
# Out:
# Area of circle is 346.36
