# %%
n1 = int(input("Enter a number"))
n2 = int(input("Enter a number"))
n3 = int(input("Enter a number"))
print(" ascending ...")
f= None
s = None 
t = None
# first
if n1 < n2 and n1 < n3:
    f=n1
elif n1 < n3 and n1 > n2:
    s = n1
elif n1 >n3 and n1 < n2:
    s = n1
elif n1 > n2 and n1 > n3:
    t = n1

# second number
if n2 < n1 and n2 < n3:
    f = n2
elif n2 > n1 and n2 < n3:
    s = n2
elif n2 > n1 and n2 > n3:
    t = n2
elif n2 < n3 and n2 > n1:
    s = n2
 # third number
if n3 < n1 and n3 < n2:
    f = n3  
elif n3 < n2 and n3 > n1:
    s = n3
elif n3 > n2 and n3 < n1:
    s = n3
elif  n3 > n2 and n3 > n2:
    t = n3

print( f"first number is {f}, second is {s}, third is {t}")
# Out:
#  ascending ...
# first number is 45, second is 67, third is 90
