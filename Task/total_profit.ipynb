# %% [markdown]
# count total profit
# cost = 1.25
# profit  margin = 20%
# profit per bag = profit margin *cost
# no of bag =500
# total = no of bag * profit per bag

# %%
cost = float(input("Enter cost of an item"))
profit_margin = float(input('enter profit percentage per item'))
profit_per_item = profit_margin/100 * cost

no_of_item = int(input('enter total no of items'))
total_profit = no_of_item * profit_per_item

print(f"COST PER ITEM: {cost:>10} \n PROFIT PER ITEM: {profit_per_item:>10}\n No of item: {no_of_item:>10} \n TOTAL:{total_profit:>10} ")
# Out:
# COST PER ITEM:       1.25
#  PROFIT PER ITEM:       0.25
#  No of item:        500
#  TOTAL:     125.0
