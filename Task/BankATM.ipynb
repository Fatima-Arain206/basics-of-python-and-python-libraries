# %%
saved_pin ="3974"
saved_balance = 5600
card_insert= False
insertion = input("did you enter your card y/n")
if insertion == "y":
    card_insert = True

    enteredP = input("Enter your pin ") 
    if saved_pin == enteredP:

        withdraw = int(input("enter amount")) 
        if  withdraw >= saved_balance:
            print("check your balance range") 
        else:
         print("enjoy ....")   
    else:
        print("incorrect pin")
else:
   card_insert= False 
   print("insert card")
# Out:
# check your balance range
