# %%
password = input(" set a password is should b contains char numbers and special letters" \
"and minimum size should b 8")
if len(password) < 8:
    password=input("maintain password minimum 8 chars")
for j in password:
        if j ==' ':
            print("don't add space!!!!😡🤬")
            break
password=input("maintain password minimum 8 chars")
    
if password =="12345678" or password =="87654321" or password =="password":
        print("password is weak")
else:
      print("okk this is strong password ")
# Out:
# don't add space!!!!😡🤬
# okk
