# %%
unit = int(input(" Enter consumed units"))
perU = None
total_bill =0
if unit <=100:
    perU =5
    total_bill = unit*perU
elif unit > 100 and unit <= 200:
    perU = 10
    total_bill = unit*perU
elif unit> 200 and unit <=300:
    perU = 15
    total_bill = unit*perU

print(" total bill is ",total_bill," with unit",unit,"per unit is ",perU)
# Out:
#  total bill is  1500  with unit 150 per unit is  10
