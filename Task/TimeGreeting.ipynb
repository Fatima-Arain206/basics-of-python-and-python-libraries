# %%
time = int(input(" Enter time  1 - 24"))
if time >= 5 and time <= 11:
    print("good morning")
elif time >=12 and time <=17:
    print("Good after noon")
elif time >= 18 and time <= 24:
    print("good evening")    
else:
    print(" wrong time")
# Out:
# good morning
