# %%
x = int(input("x =?"))
y = int(input("y =?"))
if x==0 and y == 0:
    print("origin")
elif x >0 and y>0:
    print("Quadrant I both x ,y are positive")    
elif x < 0 and y > 0:
        print("Quadrant II  x is negative ,y is positive")    
elif   x < 0 and y < 0:
         print("Quadrant III both x ,y are negative")    
elif x >0 and y < 0:
          print("Quadrant IV  x  positive,y is positive")  
else:
       print("enter again")
# Out:
# Quadrant IV  x  positive,y is positive
