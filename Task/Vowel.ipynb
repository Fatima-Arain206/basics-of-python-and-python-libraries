# %%
ch = input("enter a single char ")
if len(ch)>1:
    print("Wrong input")
    ch = input("enter a single char ")

if ch.isdigit():
    print("Not an alphabet")
elif ch == 'a' or ch=='i' or ch=='e' or ch =='u' or ch =='o':
   print(ch," is Vowel") 
else:
    print(ch,"constant")
# Out:
# Not an alphabet
