# %%
start1 = int(input("Enter first start "))
end1 = int(input("Enter first end "))
start2 = int(input("Enter second start "))
end2 = int(input("Enter second end "))
if start1 <= end2 and start2 <= end1:
    print("overlap")
else:
    print("not over lap")
# Out:
# not over lap

# %% [markdown]
# jo
