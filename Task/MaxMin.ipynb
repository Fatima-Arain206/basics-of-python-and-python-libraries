# %%
num1 = float(input("Enter first num \n"))
num2 = float(input("Enter first num \n"))

# %%
if num1 > num2:
    print(f"{num1} is max \n and {num2 } is min")
else:
    print(f"{num2} is max \n and {num1} is min")
# Out:
# 6.0 is max
#  and 4.0 is min

# %% [markdown]
# # my first mark down
# ## iam happy to know this
