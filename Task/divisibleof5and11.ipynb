# %%
n = int(input(" enter a number "))

# %%
if n % 5 == 0 and n % 11 ==0:
    print(n,"is divisible by 5 and 11")
elif n %  5 == 0:
    print(print(n,"is divisible by 5 "))
else:
    print(n,"is divisible by 11")
# Out:
# 66 is divisible by 11
