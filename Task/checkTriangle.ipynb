# %%
a = int(input(" first side of triangle"))
b = int(input(" first second of triangle"))
c = int(input(" first third of triangle"))
position = None
if a == b and a ==c and c== b:
   position=  "equilateral , all sides"
   print(position)
elif a == b  or b ==c or c==a :
   position = " Isosceles ,two sides are equal "
   print(position)
else:
   position = " Scalene all sides are different "
   print(position)
# Out:
#  Scalene all sides are different
