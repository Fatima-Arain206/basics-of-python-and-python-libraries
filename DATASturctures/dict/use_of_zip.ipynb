# %%
from unittest import result

name=['fatima','zeeshan','ali','surhan','maida']
marks=[99,98,79,80,89]

# %%
result_keys_name=dict( zip(name , marks))
result_keys_name

print(result_keys_name['ali'])

result_keys_marks = dict (zip(marks,name))
print(result_keys_marks[79])
# note if the keys are same marks and names will be replaced
# Out:
# 79
# ali
