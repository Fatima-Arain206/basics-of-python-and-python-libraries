# %% [markdown]
# studend={
# 'name':"Fatima"
# 'roll_no':"2K25/28/BLCS"
# 'major'
# }

# %%
student={
'name':"Fatima",
'roll_no':"2K25/28/BLCS",
'major':"Database"
}
print(student['major'])
# Out:
# Database

# %%
# adding a new key
student['gpa']=3.78
# update last one
student['major']='Data science'
# updating with a new dictionry
student.update({'major':"ML",'gpa':9.67})
student.update({'sem':2})
student['email']='arain.com'

# %%
# del vs pop

# student.pop('major')# deleted the key
student
del student['gpa']

# %%
print(student)
print(student.items())
# Out:
# {'name': 'Fatima', 'roll_no': '2K25/28/BLCS', 'email': 'arain.com', 'sem': 2}
# dict_items([('name', 'Fatima'), ('roll_no', '2K25/28/BLCS'), ('email', 'arain.com'), ('sem', 2)])
