# %%
def max_val(dic):
    try:
         return max(dic.values())

    except TypeError:
        print('enter only dictionry values with number')
a={11: 1, 2: 2, 23: 1, 3: 2, '2': 'd', 7: 2, 4: 1, 5: 1}
max_val(a)
# Out:
# enter only dictionry values with number

# %%
def max_val(dic):
    try:
        lsi=[dic[x] for x in dic]
        maxi=float('-inf')
        for i in range(0,len(lsi)-1):
             if lsi[i] > maxi:
                 maxi=lsi[i]
    except ValueError:
        print("enter number")
    except TypeError:
        print(" enter numbers in values")
    else:
        return maxi


max_val(a)
# Out:
#  enter numbers in values
# 2
