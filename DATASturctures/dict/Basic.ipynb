# %% [markdown]
# studend={
# 'name':"Fatima"
# 'roll_no':"2K25/28/BLCS"
# 'major'
# }

# %%
student={
'name':"Fatima",
'roll_no':"2K25/28/BLCS",
'major':"Database"
}
print(student['major'])
# Out:
# Database

# %%
# adding a new key
student['gpa']=3.78
# update last one
student['major']='Data science'
# updating with a new dictionry
student.update({'major':"ML",'gpa':9.67})
student.update({'sem':2})
student['email']='arain.com'

# %%
print(student)
print(student.items())
# Out:
# {'name': 'Fatima', 'roll_no': '2K25/28/BLCS', 'major': 'ML', 'gpa': 9.67, 'sem': 2, 'email': 'arain.com'}
# dict_items([('name', 'Fatima'), ('roll_no', '2K25/28/BLCS'), ('major', 'ML'), ('gpa', 9.67), ('sem', 2), ('email', 'arain.com')])

# %%
print(student.pop('major'))
print(student)
# Out:
# ML
# {'name': 'Fatima', 'roll_no': '2K25/28/BLCS', 'gpa': 9.67, 'sem': 2, 'email': 'arain.com'}

# %%
# del student['gpa']
print(student)
# Out:
# {'name': 'Fatima', 'roll_no': '2K25/28/BLCS', 'gpa': 9.67, 'sem': 2, 'email': 'arain.com'}

# %%
print(student['gpa'])
# Out:
# 9.67

# %%
# print(help(dict))
print(student.__sizeof__())
len(student)
n={

}
print(n.__sizeof__())
a='2'
b='3'
a is not b
# Out:
# 256
# 48
# True
