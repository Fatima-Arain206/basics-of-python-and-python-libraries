# %%
from sympy.physics.units import seconds

nested={
    101:{'fatima':'arain','cgpa':3.6},
     102:{'aqsa'
          :'ali','cgpa':3.3}, 103:{'nagma':'nizamani','cgpa':3.63}, 104:{'zees':'raj','cgpa':3.90},

}
# acces second
print(nested[101])
inner= nested[101]
machine = iter(nested[101])
first_key=next(machine)
seconds_key=next(machine)
print(first_key)
print(seconds_key)
n
# stunt2
# Out:
# {'fatima': 'arain', 'cgpa': 3.6}
# fatima
# cgpa
