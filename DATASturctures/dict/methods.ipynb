# %%
team=[
    ("ali",23,'center'),
    ('hadi',24,'center'),
    ('shani',26,'right'),
    ('maryam',21,'left'),
    ("messi",41,'west'),
    ('doland',21,'north'),
    ("kuba",34,'center')

]
new_team={}
for name,age,positon in team:
    if positon in new_team:
        new_team[positon].append((name,age))
    else:
        new_team[positon]=[(name,age)]
new_team["center"]
# Out:
# [('ali', 23), ('hadi', 24), ('kuba', 34)]

# %% [markdown]
# f you run a loop over a dictionary, ​the loop will only access the keys, not the values. ​F

# %%
for x in new_team:
    print(x,new_team[x])
# Out:
# center [('ali', 23), ('hadi', 24), ('kuba', 34)]
# right [('shani', 26)]
# left [('maryam', 21)]
# west [('messi', 41)]
# north [('doland', 21)]

# %% [markdown]
#  ​The keys method lets you retrieve ​only the dictionary's keys

# %%
new_team.keys()
# Out:
# dict_keys(['center', 'right', 'left', 'west', 'north'])

# %% [markdown]
# Similarly, the values method lets you retrieve ​only the dictionary's values. ​When applied to our "new_team" dictionary

# %%
new_team.values()
# Out:
# dict_values([[('ali', 23), ('hadi', 24), ('kuba', 34)], [('shani', 26)], [('maryam', 21)], [('messi', 41)], [('doland', 21)]])

# %% [markdown]
# both the keys and their values?
# ​You can, using the items method, which lets you retrieve ​both the dictionary's keys and values.

# %%
a=new_team.items()
type(a)
# Out:
# dict_items

# %% [markdown]
# To delete a key-value pair from a dictionary, use the del keyword:

# %%
del new_team['left']
# new_team
print(new_team.items())
new_team.keys()
# Out:
# dict_items([('center', [('ali', 23), ('hadi', 24), ('kuba', 34)]), ('right', [('shani', 26)]), ('west', [('messi', 41)]), ('north', [('doland', 21)])])
# dict_keys(['center', 'right', 'west', 'north'])
