# %%
# keys shuold be 1 - 10 and values should be their sq

sq={ x:x**2 for x in range(1,11)}
print(sq.items())
sq
# Out:
# dict_items([(1, 1), (2, 4), (3, 9), (4, 16), (5, 25), (6, 36), (7, 49), (8, 64), (9, 81), (10, 100)])
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
# filter values less than 50
filtered={x:sq[x ]  for x in sq if sq[x]<=50}
type(filtered)
filtered
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
