# %%
st=[('fatima',3.8),('hina',3.5),('ali',4.5)]
# lets sort
key=lambda x:x[1]
sorted(st,key=lambda x:x[1])
print(st)
# Out:
# [('fatima', 3.8), ('hina', 3.5), ('ali', 4.5)]

# %%
a=tuple(x**2  for x in range(4))
a
# Out:
# (0, 1, 4, 9)

# %%
res=[(11,'fail'),(3,'abs'),(9,'pass'),(6,'fail'),(5,'abs'),(7,'pass'),(1,'fail'),(9,'abs')]
pas=tuple( res[x] for x in range(len(res)) if res[x][1]=='pass')
pas
# Out:
# ((9, 'pass'), (7, 'pass'))
