# %%
import collections
from collections import namedtuple

from zope.interface.common import collections

a=namedtuple('Fatima',"coding")
b=('fatima','coding')
a[0]
print(a.Fatima)
print(b[0]) # ????? wait
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       7 b=('fatima','coding')
#       8 a[0]
# ----> 9 print(a.Fatima)
#      10 print(b[0])
#
# AttributeError: type object 'Fatima' has no attribute 'Fatima'
