# %%
user=('Fatima',"admin",'whatsp','insta')
# change admin to superadmin
user=list(user)
user[1]="superAdmin"
user=tuple(user)
print(user)
print(type(user))
# Out:
# ('Fatima', 'superAdmin', 'whatsp', 'insta')
# <class 'tuple'>

# %%
# concantenation
t1=(1,2,3,4,5,6,)
# add 7,8
t1=t1+(7,8)
print(t1)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)
