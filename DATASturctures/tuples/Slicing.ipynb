# %%
a=(10,30,20,50,60,70,90,80)
print(a[::-1])
# Out:
# (80, 90, 70, 60, 50, 20, 30, 10)

# %% [markdown]
# slicing always retrun a new tuple

# %%
# print 2 step
print(a[0:-1:2])
# Out:
# (10, 20, 60, 90)

# %%
# count
respones=('yes','yes','no','yes','no','yes','yes','no','yes','no')
print(respones.count('yes'))
# Out:
# 6

# %%
# index
try :
    print(respones.index('no'))
except ValueError:
    print('index not found')
# Out:
# 2
