# %%
pack=('Fatima',"2k25/bl900",3.578)
# unpack=
name,roll_no,_= pack # the dummy varilable
print(name , roll_no ,_ )
pack_li=list(pack)
name,roll_no,_ = pack_li
print(name , roll_no , cgpa)

# %%
# * ignore
name , *ignore = pack
print(name ,)
