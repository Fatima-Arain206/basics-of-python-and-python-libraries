# %%
student=('Fatima','CS/229',[3.45, 2,2])
print(student)
student[2].insert(0,3.67) # insert index
# add
student[2].append(99)
student[2].remove(3.45)
print(student)
# Out:
# ('Fatima', 'CS/229', [3.45, 2, 2])
# ('Fatima', 'CS/229', [3.67, 2, 2, 99])
