# %%
import sys
a=tuple()
b=list()
print(f'tuples {sys.getsizeof(a)}')
print(f'list {sys.getsizeof(b)}')
print()
b.append(2)
b.append(3)
b.append(4)
b.append(5)
a=(2,3,4,5,3)
print(f'tuples {sys.getsizeof(a)}')# base 40 + 8 *4
print(f'list {sys.getsizeof(b)}')# base 56 + 8*4*2
# wait
# Out:
# tuples 40
# list 56
#
# tuples 80
# list 88
