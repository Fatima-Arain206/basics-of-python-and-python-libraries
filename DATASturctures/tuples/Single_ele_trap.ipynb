# %%
s= (4)
print(type(s))# this will not consider as tuple
b=(4,) # comma is necessary
print(type(b))

#

# %%
item=( 'Fatima')
print(type(item))
# make a tuple
tu_item = tuple('FAtima')
print((type(tu_item)))
print(tu_item)
# Out:
# <class 'str'>
# <class 'tuple'>
# ('F', 'A', 't', 'i', 'm', 'a')

# %%
data =('a','b','c','d','e')
# unpack only first and last
first,*middle,last = data
print(first , last)
print(type(middle))
# Out:
# a e
# <class 'list'>

# %%
task=(100,90,86,45,67,89,63,2,3,5)
high , *remian =task
print(high , remian)
# Out:
# 100 [90, 86, 45, 67, 89, 63, 2, 3, 5]
