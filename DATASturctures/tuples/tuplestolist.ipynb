# %%
state_county_tuples=[(' Arizona', 'Maricopa'),
 ('California', 'Alameda'),
 ('California', 'Sacramento '),
 ('Kentucky', 'Jefferson'),
 ('Louisiana', 'East Baton Rouge')]

ca_counties=[]
for  ca in range(len(state_county_tuples)):
    if "California" in state_county_tuples[ca] :
        ca_counties.append(state_county_tuples[ca][1])
ca_counties
# Out:
# ['Alameda', 'Sacramento ']

# %%
ca_countie=[state_county_tuples[ca][1] for ca in range(len(state_county_tuples))   if "California" in state_county_tuples[ca] ]
print(ca_countie)
# Out:
# ['Alameda', 'Sacramento ']
