# %%
l1=[1,2]
l2=[1,2]
print(l1 is l2)
print(id(l1))
print(id(l2))
print(l1==l1)
# Out:
# False
# 1331545256064
# 1333572320256
# True

# %%
t1=(1,2)
t2=(1,2)
print(t1 is t2)
print(id(t1))
print(id(t2))

print(t1==t2)
# Out:
# False
# 1333572591296
# 1333566838080
# True

# %%
print(hash(t1))
# Out:
# -3550055125485641917

# %%
# d={(1,2,[5,6]) : 1} # thiss is not possible

# %%
t=(1,2,[3,4])

print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 t=(1,2,[3,4])
# ----> 2 t[2]+=[5]
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# generator
gen=(x**2 for x in range(8))
gen
a=tuple(gen)
a
# Out:
# (0, 1, 4, 9, 16, 25, 36, 49)
