# %%
s={1,4,5,6,7,8,9,2,10}
print(set(x for x in range(1,11)).difference(s))
# Out:
# {3}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 print(set(x for x in range(1,11)).difference(s))
#       3 n=s
# ----> 4 dif= (n + 1)/2
#       5 dif
#
# TypeError: unsupported operand type(s) for +: 'set' and 'int'
