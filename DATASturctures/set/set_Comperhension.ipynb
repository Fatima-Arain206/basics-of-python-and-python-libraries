# %%
from distutils.dir_util import remove_tree

st={ x for  x in range(31) if x % 3==0 or x % 5==0}
for i in st:
    print(i)
# Out:
# 0
# 3
# 5
# 6
# 9
# 10
# 12
# 15
# 18
# 20
# 21
# 24
# 25
# 27
# 30

# %%
# subset query
def subset_zero():
    exp=[10,5,-15,20]
    st=set()
    balance=0
    for x in exp:
        balance=balance+x
        if balance == 0:
            return True
        else:
            st.add(balance)
    return False


subset_zero()
# Out:
# True
