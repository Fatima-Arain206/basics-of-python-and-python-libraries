# %%
a={4,56,7,89,}
b={9,8,7,6,5,43,3,1,2,3,4,56,7,89,}
'''check is a subset of b  and is b superset of a'''
# print(a.issubset(b))
# print(b.issuperset(a))


# print(a.add(311))
# print(a)# remove from starting
# print(a.pop())
# print(a)
print(a.pop())
print(a)
# print(a.remove())
# Out:
# 56
# {89, 4, 7}

# %%
# frozenset this is set which can not be change

# %%
ass=frozenset({3,5,7,890})
ass
# Out:
# frozenset({3, 5, 7, 890})
