# %%
# convert a list into a set with unique elements
a=[1,2,86,4,2,211,0,65,5]
a=set(a)
a

# %%
name_set=set()
name_set.add('C++')
name_set.add('JAVA')
name_set.add('PYTHON')
name_set.add('RUBBY')
name_set.add('R')

name_set.add('sql')
name_set.add('assembly')
name_set
# Out:
# {'C++', 'JAVA', 'PYTHON', 'R', 'RUBBY', 'assembly', 'sql'}

# %%
# remove and discard
print(name_set.discard('C++'))
print()
# name_set.remove('RUBBY') # if element not found thruogh error

name_set.discard('RUBBY')#
# name_set

'PYTHON' in name_set
# Out:
# None
# True

# %%
# deletes se
name_set.clear() # delete internal data
name_set
del name_set # delete  object from memory
name_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # deletes se
# ----> 2 name_set.clear()
#       3 name_set
#       4 del name_set
#
# NameError: name 'name_set' is not defined
