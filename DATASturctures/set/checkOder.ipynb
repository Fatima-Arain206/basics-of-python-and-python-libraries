# %%
a={1,56,7,80,87,63,2,51,3,99}
for x in  a:
    print(x,end=' ')
# first attempt 1 2 3 7 80 51 87 56 63
# this return unorder set
b=a
b
# Out:
# 1 2 99 3 7 80 51 87 56 63
# {1, 2, 3, 7, 51, 56, 63, 80, 87, 99}

# %%
st="university"
st=set(st)
st
# Out:
# {'e', 'i', 'n', 'r', 's', 't', 'u', 'v', 'y'}

# %%
s1={1,2,3,4,5,6}
s2={9,7,5,109,76,5}
print(s1.update(s2))
print(s1)# it adds (union) s2 to s1
print(s1.intersection_update(s2))# only removes all elements only left those who are common elements
print(s1)
# Out:
# None
# {1, 2, 3, 4, 5, 6, 7, 9, 76, 109}
# None
# {5, 7, 9, 76, 109}

# %%
# frozen vs set

# st={1,2,3,4,set({3,89,6})}# this is not possible nested set
st={1,2,4,5,frozenset({1,2,37,89}),90,65,432,'fatima',"cat","act"}
st
print(type(st))
print(hash('fatima'))
print(hash(1)==1)
print(hash('cat')=='act')# the hash function calculate the char position and assci value and genrat a random integer
print(hash('cat'),hash('act'))
# print(-4539285623313428164)
# Out:
# <class 'set'>
# 8723707379340000862
# True
# False
# -4539285623313428164 3266891973538051466
# -4539285623313428164

# %% [markdown]
# the set data structes works on hash functions, they didnot use index and id() the time complexity is O(1) and
# it store unique data the hash aderess will be same for one value and will not add again and again
