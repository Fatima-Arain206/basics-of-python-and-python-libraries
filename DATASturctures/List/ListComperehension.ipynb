# %%
sq=[]
for i in range(10):
    sq.append(i**2)
    print(sq[i],' ')

# %%
## smart way
square=[n**2 for n in range(10)]# n squar will added in list
print(square)

# %%
price=[10,20,30]
price=[i*2 for i in price]
print(price)

# %%
age=[12.3,67,35,97,34]
adult=[a for a in age if a > 18]
print(adult)

# %%
n= [1,3,4,6,8,9,75,3,221,53,21,22,12,4,6,]
even=[e for e in  n if e%2==0 ]
# print(even)

# %%
a=[12,3,4,6,78,42,8,3,2,6,8,0]
# print(a[:3])
# print(a[-3:])
# print(a[-1:-3:-1])
a[:3]=[33,55,78]
# print(a)

# %%
x=90
print(x.imag)
x=x+2
print(x.real)
print(x.imag)
# x.bit_length
c=12+3j
d= 13+3

# print(c.imag)
# print(x.bit_length())

# %%
t=(1,2,3,4)
print(t)
t=5,6,7,8,6,4,3,2,1
print(t)

# %%
a=["fatima","ali","bilal","aqsa","Ng","andrew"]
b="aqsa"
od= a.index(b)
ans = od > len(a)/2 and od!= len(a)-1

print(od)

# %%
n= "fatima"
d="d-64-6783 245 -64 "
print(c+'!' for c in n)
print(n.upper())
print(n.startswith("a"))
print(n.endswith("a"))
c=d.split("3")
print(c)
ok=["my name","is","fatima"]
print('!'.join(ok))
print(ok)

# %%
import  math
print("its math babe".format(type(math)))
print(type(math))
# print(dir(math))
print(dir(str))

# %%
print("pi to 4 significant digits = {:.2f}".format(math.pi))
print("age is {}".format(math.e))

# %%
import math as m
print(m.pi)

# %%
from math import *
print(pi)
print(round(log(33,5)))

# %%
# from learntool.python import a
